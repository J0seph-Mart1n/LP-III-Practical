# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('archive/sales_data_sample.csv', encoding='Latin-1')

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0      2/24/2003 0:00   Shipped       1         2     2003  ...
# 1       5/7/2003 0:00   Shipped       2         5     2003  ...
# 2       7/1/2003 0:00   Shipped       3         7     2003  ...
# 3      8/25/2003 0:00   Shipped       3         8     2003  ...
# 4     10/10/2003 0:00   Shipped       4        10     2003  ...
# ...               ...       ...     ...       ...      ...  ...
# 2818   12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819   1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820    3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821   3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822    5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                        ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0           897 Long Airport Avenue           NaN            NYC    NY
# 1                59 rue de l'Abbaye           NaN          Reims   NaN
# 2     27 rue du Colonel Pierre Avia           NaN          Paris   NaN
# 3                78934 Hillside Dr.           NaN       Pasadena    CA
# 4                   7734 Strong St.           NaN  San Francisco    CA
# ...                             ...           ...            ...   ...
# 2818             C/ Moralzarzal, 86           NaN         Madrid   NaN
# 2819                    Torikatu 38           NaN           Oulu   NaN
# 2820             C/ Moralzarzal, 86           NaN         Madrid   NaN
# 2821          1 rue Alsace-Lorraine           NaN       Toulouse   NaN
# 2822             8616 Spinnaker Dr.           NaN         Boston    MA
#
#      POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0         10022      USA       NaN              Yu             Kwai    Small
# 1         51100   France      EMEA         Henriot             Paul    Small
# 2         75508   France      EMEA        Da Cunha           Daniel   Medium
# 3         90003      USA       NaN           Young            Julie   Medium
# 4           NaN      USA       NaN           Brown            Julie   Medium
# ...         ...      ...       ...             ...              ...      ...
# 2818      28034    Spain      EMEA          Freyre            Diego    Small
# 2819      90110  Finland      EMEA       Koskitalo           Pirkko   Medium
# 2820      28034    Spain      EMEA          Freyre            Diego   Medium
# 2821      31000   France      EMEA          Roulet          Annette    Small
# 2822      51003      USA       NaN         Yoshido             Juri   Medium
#
# [2823 rows x 25 columns]

# %%
df.shape
# Out:
# (2823, 25)

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df.drop(['ORDERNUMBER','ORDERDATE','CUSTOMERNAME','PHONE','ADDRESSLINE1','ADDRESSLINE2','CITY','STATE','POSTALCODE','TERRITORY','CONTACTLASTNAME','CONTACTFIRSTNAME'], axis=1, inplace=True)

# %%
df.isna().sum()
# Out:
# QUANTITYORDERED    0
# PRICEEACH          0
# ORDERLINENUMBER    0
# SALES              0
# STATUS             0
# QTR_ID             0
# MONTH_ID           0
# YEAR_ID            0
# PRODUCTLINE        0
# MSRP               0
# PRODUCTCODE        0
# COUNTRY            0
# DEALSIZE           0
# dtype: int64

# %%
df.head()
# Out:
#    QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES   STATUS  QTR_ID  \
# 0               30      95.70                2  2871.00  Shipped       1
# 1               34      81.35                5  2765.90  Shipped       2
# 2               41      94.74                2  3884.34  Shipped       3
# 3               45      83.26                6  3746.70  Shipped       3
# 4               49     100.00               14  5205.27  Shipped       4
#
#    MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP PRODUCTCODE COUNTRY DEALSIZE
# 0         2     2003  Motorcycles    95    S10_1678     USA    Small
# 1         5     2003  Motorcycles    95    S10_1678  France    Small
# 2         7     2003  Motorcycles    95    S10_1678  France   Medium
# 3         8     2003  Motorcycles    95    S10_1678     USA   Medium
# 4        10     2003  Motorcycles    95    S10_1678     USA   Medium

# %%
df.describe()
# Out:
#        QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER         SALES  \
# count      2823.000000  2823.000000      2823.000000   2823.000000
# mean         35.092809    83.658544         6.466171   3553.889072
# std           9.741443    20.174277         4.225841   1841.865106
# min           6.000000    26.880000         1.000000    482.130000
# 25%          27.000000    68.860000         3.000000   2203.430000
# 50%          35.000000    95.700000         6.000000   3184.800000
# 75%          43.000000   100.000000         9.000000   4508.000000
# max          97.000000   100.000000        18.000000  14082.800000
#
#             QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count  2823.000000  2823.000000  2823.00000  2823.000000
# mean      2.717676     7.092455  2003.81509   100.715551
# std       1.203878     3.656633     0.69967    40.187912
# min       1.000000     1.000000  2003.00000    33.000000
# 25%       2.000000     4.000000  2003.00000    68.000000
# 50%       3.000000     8.000000  2004.00000    99.000000
# 75%       4.000000    11.000000  2004.00000   124.000000
# max       4.000000    12.000000  2005.00000   214.000000

# %%
sns.countplot(data=df, x='STATUS')
# Out:
# <Axes: xlabel='STATUS', ylabel='count'>

# %%
df['PRODUCTLINE']
# Out:
# 0       Motorcycles
# 1       Motorcycles
# 2       Motorcycles
# 3       Motorcycles
# 4       Motorcycles
#            ...
# 2818          Ships
# 2819          Ships
# 2820          Ships
# 2821          Ships
# 2822          Ships
# Name: PRODUCTLINE, Length: 2823, dtype: object

# %%
sns.histplot(x='SALES', hue='PRODUCTLINE', data=df, element='poly')
# Out:
# <Axes: xlabel='SALES', ylabel='Count'>

# %%
df['PRODUCTLINE'].unique()
# Out:
# array(['Motorcycles', 'Classic Cars', 'Trucks and Buses', 'Vintage Cars',
#        'Planes', 'Ships', 'Trains'], dtype=object)

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2823 entries, 0 to 2822
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   QUANTITYORDERED  2823 non-null   int64
#  1   PRICEEACH        2823 non-null   float64
#  2   ORDERLINENUMBER  2823 non-null   int64
#  3   SALES            2823 non-null   float64
#  4   STATUS           2823 non-null   object
#  5   QTR_ID           2823 non-null   int64
#  6   MONTH_ID         2823 non-null   int64
#  7   YEAR_ID          2823 non-null   int64
#  8   PRODUCTLINE      2823 non-null   object
#  9   MSRP             2823 non-null   int64
#  10  PRODUCTCODE      2823 non-null   object
#  11  COUNTRY          2823 non-null   object
#  12  DEALSIZE         2823 non-null   object
# dtypes: float64(2), int64(6), object(5)
# memory usage: 308.8+ KB

# %%
list_cat = df.select_dtypes(include=['object']).columns.tolist()

# %%
list_cat
# Out:
# ['STATUS', 'PRODUCTLINE', 'PRODUCTCODE', 'COUNTRY', 'DEALSIZE']

# %%
for i in list_cat:
    sns.countplot(data=df, x=i)
    plt.xticks(rotation=90)
    plt.show()

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
for i in list_cat:
    df[i] = le.fit_transform(df[i])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2823 entries, 0 to 2822
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   QUANTITYORDERED  2823 non-null   int64
#  1   PRICEEACH        2823 non-null   float64
#  2   ORDERLINENUMBER  2823 non-null   int64
#  3   SALES            2823 non-null   float64
#  4   STATUS           2823 non-null   int32
#  5   QTR_ID           2823 non-null   int64
#  6   MONTH_ID         2823 non-null   int64
#  7   YEAR_ID          2823 non-null   int64
#  8   PRODUCTLINE      2823 non-null   int32
#  9   MSRP             2823 non-null   int64
#  10  PRODUCTCODE      2823 non-null   int32
#  11  COUNTRY          2823 non-null   int32
#  12  DEALSIZE         2823 non-null   int32
# dtypes: float64(2), int32(5), int64(6)
# memory usage: 253.6 KB

# %%
df['PRICEEACH'] = df['PRICEEACH'].astype(int)
df['SALES'] = df['SALES'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2823 entries, 0 to 2822
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   QUANTITYORDERED  2823 non-null   int64
#  1   PRICEEACH        2823 non-null   int32
#  2   ORDERLINENUMBER  2823 non-null   int64
#  3   SALES            2823 non-null   int32
#  4   STATUS           2823 non-null   int32
#  5   QTR_ID           2823 non-null   int64
#  6   MONTH_ID         2823 non-null   int64
#  7   YEAR_ID          2823 non-null   int64
#  8   PRODUCTLINE      2823 non-null   int32
#  9   MSRP             2823 non-null   int64
#  10  PRODUCTCODE      2823 non-null   int32
#  11  COUNTRY          2823 non-null   int32
#  12  DEALSIZE         2823 non-null   int32
# dtypes: int32(7), int64(6)
# memory usage: 231.6 KB

# %%
df.describe()
# Out:
#        QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER         SALES  \
# count      2823.000000  2823.000000      2823.000000   2823.000000
# mean         35.092809    83.392136         6.466171   3553.421537
# std           9.741443    20.361030         4.225841   1841.865754
# min           6.000000    26.000000         1.000000    482.000000
# 25%          27.000000    68.000000         3.000000   2203.000000
# 50%          35.000000    95.000000         6.000000   3184.000000
# 75%          43.000000   100.000000         9.000000   4508.000000
# max          97.000000   100.000000        18.000000  14082.000000
#
#             STATUS       QTR_ID     MONTH_ID     YEAR_ID  PRODUCTLINE  \
# count  2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean      4.782501     2.717676     7.092455  2003.81509     2.515055
# std       0.879416     1.203878     3.656633     0.69967     2.411665
# min       0.000000     1.000000     1.000000  2003.00000     0.000000
# 25%       5.000000     2.000000     4.000000  2003.00000     0.000000
# 50%       5.000000     3.000000     8.000000  2004.00000     2.000000
# 75%       5.000000     4.000000    11.000000  2004.00000     5.000000
# max       5.000000     4.000000    12.000000  2005.00000     6.000000
#
#               MSRP  PRODUCTCODE      COUNTRY     DEALSIZE
# count  2823.000000  2823.000000  2823.000000  2823.000000
# mean    100.715551    53.773291    12.029401     1.398512
# std      40.187912    31.585298     6.169774     0.592498
# min      33.000000     0.000000     0.000000     0.000000
# 25%      68.000000    27.000000     6.000000     1.000000
# 50%      99.000000    53.000000    14.000000     1.000000
# 75%     124.000000    81.000000    18.000000     2.000000
# max     214.000000   108.000000    18.000000     2.000000

# %%
X = df[['SALES','PRODUCTCODE']]

# %% [markdown]
# K Means

# %%
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans

# %%
model = KMeans()
visualizer = KElbowVisualizer(model, k=(1,12)).fit(X)
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
kmeans = KMeans(n_clusters=4, init='k-means++', random_state=0).fit(X)

# %%
kmeans.labels_
# Out:
# array([2, 2, 2, ..., 3, 0, 2])

# %%
kmeans.inertia_
# Out:
# 1043164092.8545696

# %%
kmeans.n_iter_
# Out:
# 15

# %%
kmeans.cluster_centers_
# Out:
# array([[1913.93425926,   63.19907407],
#        [8023.78238342,   28.35751295],
#        [3489.45517241,   55.50640394],
#        [5371.72523364,   40.62616822]])

# %%
from collections import Counter
Counter(kmeans.labels_)
# Out:
# Counter({2: 1015, 3: 537, 0: 1078, 1: 193})

# %%
sns.scatterplot(data=X, x='SALES', y='PRODUCTCODE', hue=kmeans.labels_)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1],
            marker="X", c="r", s=80, label="centroids")
plt.legend()
plt.show()
